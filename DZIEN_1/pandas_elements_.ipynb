# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([5,-7,8,19,45,64],index=['a','b','c','d','h','z'])
s1
# Out:
# a     5
# b    -7
# c     8
# d    19
# h    45
# z    64
# dtype: int64

# %%
sdata = {'Warszawa': 35000, 'Lublin': 71000, 'Katowice': 16000,}
s2 = pd.Series(sdata)
s2
# Out:
# Warszawa    35000
# Lublin      71000
# Katowice    16000
# dtype: int64

# %%
dataf = {
    'miasto': ['Warszawa', 'Lublin', 'Katowice','Wrocław','Gdańsk'],
    'wnioski':[156,134,155,178,112],
    'projekty':[4,3,4,4,3]
}

frame = pd.DataFrame(dataf,index=['pierwszy','drugi','trzeci','czwarty','piąty'])
frame
# Out:
#             miasto  wnioski  projekty
# pierwszy  Warszawa      156         4
# drugi       Lublin      134         3
# trzeci    Katowice      155         4
# czwarty    Wrocław      178         4
# piąty       Gdańsk      112         3

# %%
daty = pd.date_range('20240701',periods=6)
daty
# Out:
# DatetimeIndex(['2024-07-01', '2024-07-02', '2024-07-03', '2024-07-04',
#                '2024-07-05', '2024-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=daty,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2024-07-01  1.025274  0.616742  0.236744 -0.939748
# 2024-07-02 -0.839941 -0.077021  1.162840 -0.800032
# 2024-07-03  0.512175 -0.607745 -0.339030 -1.128915
# 2024-07-04 -1.103258 -0.132521 -1.084898  1.803617
# 2024-07-05 -1.750144 -0.207679 -0.254365  1.529178
# 2024-07-06  0.197270 -0.188423 -0.640624  1.564562

# %%
s = "lajkonik"
s
# Out:
# 'lajkonik'

# %%
s[1]
# Out:
# 'a'

# %%
s[1:4]
# Out:
# 'ajk'

# %%
s[::-1]
# Out:
# 'kinokjal'

# %%
# !cat data/ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
df = pd.read_csv('data/ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !cat data/ex2.csv
# Out:
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
pd.read_csv('data/ex2.csv',header=None,names=['pole_a','pole_b','pole_c','pole_d','great_message'])
# Out:
#    pole_a  pole_b  pole_c  pole_d great_message
# 0       1       2       3       4         hello
# 1       5       6       7       8         world
# 2       9      10      11      12           foo

# %%
# !cat data/csv_mindex.csv
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
parsed = pd.read_csv('data/csv_mindex.csv',index_col=['key1','key2'])
parsed
# Out:
#            value1  value2
# key2 key1
# a    one        1       2
# b    one        3       4
# c    one        5       6
# d    one        7       8
# a    two        9      10
# b    two       11      12
# c    two       13      14
# d    two       15      16

# %%
# !cat data/ex4.csv
# Out:
# # Cześć!
# a,b,c,d,message
# # Chciałem tylko trochę utrudnić Twoją pracę.
# # Kto w ogóle wczytuje pliki CSV za pomocą komputera?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
pd.read_csv('data/ex4.csv',skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !cat data/ex5.csv
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo

# %%
result = pd.read_csv('data/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
sentinels = {'message':['foo','NA'],'something':['two']}
mydata = pd.read_csv('data/ex5.csv',na_values=sentinels)
mydata
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
mydata.to_csv('data/mydata_01.csv')

# %%
import sys
mydata.to_csv(sys.stdout,sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1||5|6||8|world
# 2|three|9|10|11.0|12|

# %%
mydata.to_csv(sys.stdout,index=False,columns=['a','b','c'])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %%
myjson = mydata.to_json(orient='records')

myjson
# Out:
# '[{"something":"one","a":1,"b":2,"c":3.0,"d":4,"message":null},{"something":null,"a":5,"b":6,"c":null,"d":8,"message":"world"},{"something":"three","a":9,"b":10,"c":11.0,"d":12,"message":null}]'

# %%
jsondata = pd.read_json('data/example.json')
jsondata
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9
